# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
price1=pd.read_csv('india_onion.csv')

# %%
price1=price1.drop('Date-Monthly',axis=1)

# %%
price1=price1.astype(float)
price1
# Out:
#      India, Retail, Patna, Onions, USD/tonne Commodity Code: 71110  \
# 0                                                160.0
# 1                                                160.0
# 2                                                160.0
# 3                                                160.0
# 4                                                150.0
# ..                                                 ...
# 240                                              860.0
# 241                                              460.0
# 242                                              390.0
# 243                                              280.0
# 244                                              250.0
#
#      India, Retail, New Delhi, Onions, USD/tonne Commodity Code: 71110  \
# 0                                                170.0
# 1                                                160.0
# 2                                                160.0
# ...

# %%
x=price1.iloc[0:12].sum(axis=0)/12
x=pd.DataFrame(x)
x=x.T
x
# Out:
#    India, Retail, Patna, Onions, USD/tonne Commodity Code: 71110  \
# 0                                              130.0
#
#    India, Retail, New Delhi, Onions, USD/tonne Commodity Code: 71110  \
# 0                                              167.5
#
#    India, Retail, Mumbai, Onions, USD/tonne Commodity Code: 71110  \
# 0                                              132.5
#
#    India, Retail, Chennai, Onions, USD/tonne Commodity Code: 71110
# 0                                               92.5

# %%
count=12
sum=0;
for i in range(20):
    if i==19:
        print(count)
        sum1=(price1.iloc[count:(count+5)].sum(axis=0))/5
        sum1=pd.DataFrame(sum1)
        sum1=sum1.transpose()
        x=x.append(sum1)
        break;
    sum1=(price1.iloc[count:(count+12)].sum(axis=0))/12
    sum1=pd.DataFrame(sum1)
    sum1=sum1.transpose()
    x=x.append(sum1)
    count=count+12;
# Out:
# 240

# %%
x
# Out:
#    India, Retail, Patna, Onions, USD/tonne Commodity Code: 71110  \
# 0                                         130.000000
# 0                                         161.666667
# 0                                         130.833333
# 0                                         146.666667
# 0                                         204.166667
# 0                                         207.500000
# 0                                         135.833333
# 0                                         280.833333
# 0                                         197.500000
# 0                                         250.833333
# 0                                         336.666667
# 0                                         332.500000
# 0                                         207.500000
# 0                                         477.500000
# 0                                         317.500000
# 0                                         424.166667
# ...

# %%
list1=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]

# %%
df= pd.DataFrame(list1,columns=['Dates'])

# %%
idx=0
x.insert(loc=idx, column='Year', value=list1)

# %%
x
# Out:
#    Year  India, Retail, Patna, Onions, USD/tonne Commodity Code: 71110  \
# 0  2000                                         130.000000
# 0  2001                                         161.666667
# 0  2002                                         130.833333
# 0  2003                                         146.666667
# 0  2004                                         204.166667
# 0  2005                                         207.500000
# 0  2006                                         135.833333
# 0  2007                                         280.833333
# 0  2008                                         197.500000
# 0  2009                                         250.833333
# 0  2010                                         336.666667
# 0  2011                                         332.500000
# 0  2012                                         207.500000
# 0  2013                                         477.500000
# 0  2014                                         317.500000
# ...

# %%
x.to_csv('new_india_onion.csv');

# %% [markdown]
# ## INDIA WHEAT

# %%
price1=pd.read_csv('india_wheat.csv')
price1=price1.drop('Date-Monthly',axis=1)
price1=price1.astype(float)
price1
x=price1.iloc[0:12].sum(axis=0)/12
x=pd.DataFrame(x)
x=x.T
x
count=12
sum=0;
for i in range(20):
    if i==19:
        print(count)
        sum1=(price1.iloc[count:(count+5)].sum(axis=0))/5
        sum1=pd.DataFrame(sum1)
        sum1=sum1.transpose()
        x=x.append(sum1)
        break;
    sum1=(price1.iloc[count:(count+12)].sum(axis=0))/12
    sum1=pd.DataFrame(sum1)
    sum1=sum1.transpose()
    x=x.append(sum1)
    count=count+12;
x
# Out:
# 240
#    India, Retail, New Delhi, Wheat, USD/tonne Commodity Code: 1001   \
# 0                                         165.833333
# 0                                         152.500000
# 0                                         149.166667
# 0                                         169.166667
# 0                                         187.500000
# 0                                         203.333333
# 0                                         236.666667
# 0                                         285.000000
# 0                                         298.333333
# 0                                         279.166667
# 0                                         309.166667
# 0                                         328.333333
# 0                                         315.833333
# 0                                         311.666667
# 0                                         310.833333
# 0                                         296.666667
# ...

# %%
list1=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
idx=0
x.insert(loc=idx, column='Year', value=list1)
x
# Out:
#    Year  India, Retail, New Delhi, Wheat, USD/tonne Commodity Code: 1001   \
# 0  2000                                         165.833333
# 0  2001                                         152.500000
# 0  2002                                         149.166667
# 0  2003                                         169.166667
# 0  2004                                         187.500000
# 0  2005                                         203.333333
# 0  2006                                         236.666667
# 0  2007                                         285.000000
# 0  2008                                         298.333333
# 0  2009                                         279.166667
# 0  2010                                         309.166667
# 0  2011                                         328.333333
# 0  2012                                         315.833333
# 0  2013                                         311.666667
# 0  2014                                         310.833333
# ...

# %%
x.to_csv('new_india_wheat.csv')

# %% [markdown]
# ## India Rice

# %%
price1=pd.read_csv('india_rice.csv')
price1=price1.drop('Date-Monthly',axis=1)
price1=price1.astype(float)
price1
x=price1.iloc[0:12].sum(axis=0)/12
x=pd.DataFrame(x)
x=x.T
x
count=12
sum=0;
for i in range(20):
    if i==19:
        print(count)
        sum1=(price1.iloc[count:(count+5)].sum(axis=0))/5
        sum1=pd.DataFrame(sum1)
        sum1=sum1.transpose()
        x=x.append(sum1)
        break;
    sum1=(price1.iloc[count:(count+12)].sum(axis=0))/12
    sum1=pd.DataFrame(sum1)
    sum1=sum1.transpose()
    x=x.append(sum1)
    count=count+12;
x
# Out:
# 240
#    India, Retail, Chennai, Rice, USD/tonne Commodity Code: 1006   \
# 0                                         255.000000
# 0                                         229.166667
# 0                                         218.333333
# 0                                         241.666667
# 0                                         245.833333
# 0                                         260.833333
# 0                                         265.000000
# 0                                         319.166667
# 0                                         383.333333
# 0                                         405.833333
# 0                                         458.333333
# 0                                         475.833333
# 0                                         491.666667
# 0                                         549.166667
# 0                                         521.666667
# 0                                         462.500000
# ...

# %%
list1=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
idx=0
x.insert(loc=idx, column='Year', value=list1)
x
# Out:
#    Year  India, Retail, Chennai, Rice, USD/tonne Commodity Code: 1006   \
# 0  2000                                         255.000000
# 0  2001                                         229.166667
# 0  2002                                         218.333333
# 0  2003                                         241.666667
# 0  2004                                         245.833333
# 0  2005                                         260.833333
# 0  2006                                         265.000000
# 0  2007                                         319.166667
# 0  2008                                         383.333333
# 0  2009                                         405.833333
# 0  2010                                         458.333333
# 0  2011                                         475.833333
# 0  2012                                         491.666667
# 0  2013                                         549.166667
# 0  2014                                         521.666667
# ...

# %%
x.to_csv('new_india_rice.csv')

# %% [markdown]
# ## India Quantity

# %%
quantity= pd.read_csv('india_quantity_2018.csv')

# %%
quantity
# Out:
#    Domain Code Domain  Area Code   Area  Element Code     Element  Item Code  \
# 0           QC  Crops        100  India          5510  Production        403
# 1           QC  Crops        100  India          5510  Production        403
# 2           QC  Crops        100  India          5510  Production        403
# 3           QC  Crops        100  India          5510  Production        403
# 4           QC  Crops        100  India          5510  Production        403
# 5           QC  Crops        100  India          5510  Production        403
# 6           QC  Crops        100  India          5510  Production        403
# 7           QC  Crops        100  India          5510  Production        403
# 8           QC  Crops        100  India          5510  Production        403
# 9           QC  Crops        100  India          5510  Production        403
# 10          QC  Crops        100  India          5510  Production        403
# ...

# %%
quantity= quantity.drop(['Domain Code','Domain','Area Code','Element Code','Flag','Flag Description','Note','Year Code','Element'],axis=1)

# %%
set1=quantity.iloc[0:19]
set2=quantity.iloc[19:38]
set3=quantity.iloc[38:57]

# %%
set1.to_csv('new_india_onion_quantity.csv')
set2.to_csv('new_india_rice_quantity.csv')
set3.to_csv('new_india_wheat_quantity.csv')
